# %%
from itertools import dropwhile
import numpy as np
from db import DB
import pandas as pd
import os

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
CODE = 105560
TEST_SIZE = 150

# %%
#DB에서 데이터 가져와서 데이터프레임 만들기
db = DB()
df = db.getTable("sise", "where code = {}".format(CODE))
df = df.sort_values(by='date' ,ascending=True)
drop = df[df['date'] <= "2019.04.04"].index
df = df.drop(drop)
df.index = list(range(len(df)))
df = df[['date','open','low','high','close','diff','volume']]
#print(df)


#0~1 값으로 스케일링
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_cols = ['open', 'high', 'low', 'close', 'volume']
df_scaled = scaler.fit_transform(df[scale_cols])

df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

#
print(df_scaled)



train = df_scaled[:-TEST_SIZE]
test = df_scaled[-TEST_SIZE:]
#
feature_cols = ['open', 'high', 'low', 'volume']
label_cols = ['close']

train_feature = train[feature_cols]
train_label = train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 20)

# train, validation set 생성
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

#print(x_train.shape, x_valid.shape)

test_feature = test[feature_cols]
test_label = test[label_cols]


# test dataset (실제 예측 해볼 데이터)
test_feature, test_label = make_dataset(test_feature, test_label, 20)
#print(test_feature.shape, test_label.shape)
# ((180, 20, 4), (180, 1))
# Out:
#          open      high       low     close    volume
# 0    0.490933  0.450593  0.491613  0.484277  0.033000
# 1    0.487047  0.454545  0.492903  0.476730  0.058546
# 2    0.468912  0.440053  0.480000  0.471698  0.118448
# 3    0.457254  0.441370  0.465806  0.481761  0.163728
# 4    0.484456  0.445323  0.490323  0.481761  0.152166
# ..        ...       ...       ...       ...       ...
# 739  0.880829  0.865613  0.894194  0.881761  0.039929
# 740  0.891192  0.868248  0.858065  0.841509  0.117206
# 741  0.844560  0.836627  0.850323  0.846541  0.081653
# 742  0.839378  0.818182  0.824516  0.808805  0.123466
# 743  0.816062  0.797101  0.806452  0.808805  0.073022
#
# [744 rows x 5 columns]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from keras.layers import Dropout

model = Sequential()
model.add(LSTM(50, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = (str(CODE)+'.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0576
# Epoch 1: val_loss improved from inf to 0.00600, saving model to 105560.h5
# 29/29 [==============================] - 2s 18ms/step - loss: 0.0564 - val_loss: 0.0060
# Epoch 2/200
# 29/29 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 2: val_loss improved from 0.00600 to 0.00240, saving model to 105560.h5
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 3/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 3: val_loss improved from 0.00240 to 0.00141, saving model to 105560.h5
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 4/200
# 26/29 [=========================>....] - ETA: 0s - loss: 0.0013
# Epoch 4: val_loss did not improve from 0.00141
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 5/200
# 27/29 [==========================>...] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.00141
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 6/200
# 25/29 [========================>.....] - ETA: 0s - loss: 0.0013
# Epoch 6: val_loss improved from 0.00141 to 0.00136, saving model to 105560.h5
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 7/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 7: val_loss did not improve from 0.00136
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 8/200
# 25/29 [========================>.....] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss did not improve from 0.00136
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 9/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 9: val_loss improved from 0.00136 to 0.00129, saving model to 105560.h5
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 10/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 10: val_loss did not improve from 0.00129
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 11/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 11: val_loss improved from 0.00129 to 0.00122, saving model to 105560.h5
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 12/200
# 29/29 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 12: val_loss did not improve from 0.00122
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 13/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 13: val_loss did not improve from 0.00122
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 14/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 14: val_loss improved from 0.00122 to 0.00120, saving model to 105560.h5
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 15/200
# 27/29 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 15: val_loss did not improve from 0.00120
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 16/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss improved from 0.00120 to 0.00117, saving model to 105560.h5
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 17/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 17: val_loss improved from 0.00117 to 0.00113, saving model to 105560.h5
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 18/200
# 27/29 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 18: val_loss did not improve from 0.00113
# 29/29 [==============================] - 0s 10ms/step - loss: 9.8474e-04 - val_loss: 0.0012
# Epoch 19/200
# 24/29 [=======================>......] - ETA: 0s - loss: 9.9467e-04
# Epoch 19: val_loss improved from 0.00113 to 0.00108, saving model to 105560.h5
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 20/200
# 29/29 [==============================] - ETA: 0s - loss: 9.9448e-04
# Epoch 20: val_loss did not improve from 0.00108
# 29/29 [==============================] - 0s 10ms/step - loss: 9.9448e-04 - val_loss: 0.0013
# Epoch 21/200
# 25/29 [========================>.....] - ETA: 0s - loss: 0.0010
# Epoch 21: val_loss did not improve from 0.00108
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 22/200
# 25/29 [========================>.....] - ETA: 0s - loss: 9.7448e-04
# Epoch 22: val_loss did not improve from 0.00108
# 29/29 [==============================] - 0s 10ms/step - loss: 9.7156e-04 - val_loss: 0.0012
# Epoch 23/200
# 27/29 [==========================>...] - ETA: 0s - loss: 9.4120e-04
# Epoch 23: val_loss did not improve from 0.00108
# 29/29 [==============================] - 0s 10ms/step - loss: 9.6534e-04 - val_loss: 0.0011
# Epoch 24/200
# 28/29 [===========================>..] - ETA: 0s - loss: 9.3902e-04
# Epoch 24: val_loss improved from 0.00108 to 0.00106, saving model to 105560.h5
# 29/29 [==============================] - 0s 12ms/step - loss: 9.3254e-04 - val_loss: 0.0011
# Epoch 25/200
# 23/29 [======================>.......] - ETA: 0s - loss: 9.7872e-04
# Epoch 25: val_loss did not improve from 0.00106
# 29/29 [==============================] - 0s 12ms/step - loss: 9.7973e-04 - val_loss: 0.0012
# Epoch 26/200
# 27/29 [==========================>...] - ETA: 0s - loss: 9.0837e-04
# Epoch 26: val_loss improved from 0.00106 to 0.00102, saving model to 105560.h5
# 29/29 [==============================] - 0s 12ms/step - loss: 9.4222e-04 - val_loss: 0.0010
# Epoch 27/200
# 28/29 [===========================>..] - ETA: 0s - loss: 9.1914e-04
# Epoch 27: val_loss did not improve from 0.00102
# 29/29 [==============================] - 0s 12ms/step - loss: 9.1223e-04 - val_loss: 0.0010
# Epoch 28/200
# 27/29 [==========================>...] - ETA: 0s - loss: 9.1236e-04
# Epoch 28: val_loss did not improve from 0.00102
# 29/29 [==============================] - 0s 13ms/step - loss: 9.1198e-04 - val_loss: 0.0010
# Epoch 29/200
# 27/29 [==========================>...] - ETA: 0s - loss: 9.0169e-04
# Epoch 29: val_loss did not improve from 0.00102
# 29/29 [==============================] - 0s 14ms/step - loss: 9.2563e-04 - val_loss: 0.0010
# Epoch 30/200
# 29/29 [==============================] - ETA: 0s - loss: 8.8900e-04
# Epoch 30: val_loss improved from 0.00102 to 0.00099, saving model to 105560.h5
# 29/29 [==============================] - 0s 11ms/step - loss: 8.8900e-04 - val_loss: 9.9485e-04
# Epoch 31/200
# 27/29 [==========================>...] - ETA: 0s - loss: 9.0407e-04
# Epoch 31: val_loss improved from 0.00099 to 0.00095, saving model to 105560.h5
# 29/29 [==============================] - 0s 12ms/step - loss: 8.7757e-04 - val_loss: 9.5440e-04
# Epoch 32/200
# 28/29 [===========================>..] - ETA: 0s - loss: 8.6763e-04
# Epoch 32: val_loss improved from 0.00095 to 0.00093, saving model to 105560.h5
# 29/29 [==============================] - 0s 13ms/step - loss: 8.5775e-04 - val_loss: 9.3408e-04
# Epoch 33/200
# 27/29 [==========================>...] - ETA: 0s - loss: 8.1818e-04
# Epoch 33: val_loss did not improve from 0.00093
# 29/29 [==============================] - 0s 13ms/step - loss: 8.3753e-04 - val_loss: 9.8381e-04
# Epoch 34/200
# 28/29 [===========================>..] - ETA: 0s - loss: 8.2866e-04
# Epoch 34: val_loss did not improve from 0.00093
# 29/29 [==============================] - 0s 13ms/step - loss: 8.2155e-04 - val_loss: 9.5176e-04
# Epoch 35/200
# 26/29 [=========================>....] - ETA: 0s - loss: 8.9432e-04
# Epoch 35: val_loss did not improve from 0.00093
# 29/29 [==============================] - 0s 13ms/step - loss: 8.7577e-04 - val_loss: 9.6096e-04
# Epoch 36/200
# 26/29 [=========================>....] - ETA: 0s - loss: 9.2259e-04
# Epoch 36: val_loss did not improve from 0.00093
# 29/29 [==============================] - 0s 14ms/step - loss: 8.9974e-04 - val_loss: 9.8415e-04
# Epoch 37/200
# 28/29 [===========================>..] - ETA: 0s - loss: 8.1058e-04
# Epoch 37: val_loss did not improve from 0.00093
# 29/29 [==============================] - 0s 12ms/step - loss: 8.0156e-04 - val_loss: 0.0010

# %%
# weight 로딩
model.load_weights(filename)

# 예측
pred = model.predict(test_feature)
pred_train = model.predict(train_feature)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

plt.plot(train_label, label='actual')
plt.plot(pred_train, label='prediction')
plt.show
# %%
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
